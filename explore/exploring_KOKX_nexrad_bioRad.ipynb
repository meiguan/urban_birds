# %% [markdown]
# ### Exploring NEXRAD data - KOKX - Brookhaven, NY using BIORAD
# This is an exploratory notebook to learn and understand the functionality of the BioRAD package in R
# https://onlinelibrary.wiley.com/doi/full/10.1111/ecog.04028

# %%
library(bioRad, quietly = T)
library(Hmisc, quietly = T)
HOME = '/gws_gpfs/projects/project-urban_birds/workspace' # this is unique
file.exists(HOME)
setwd(HOME)
# set session time zone to UTC
Sys.setenv(TZ = "UTC")
# Out:
# Welcome to bioRad version 0.5.0
#
# ...
#
# ...
#
# To enable Docker functionality, start Docker and run 'check_docker()'
# in R
#
#
# Attaching package: ‘Hmisc’
#
#
# The following objects are masked from ‘package:base’:
#
#     format.pval, units
# [1] TRUE

# %% [markdown]
# ### Visualize the MTR Variable Per Year

# %%
files <- c('KOKX2016night.RData', 'KOKX2017night.RData', 
           'KOKX2018night.RData', 'KOKX2019night.RData')
years <- c('2016', '2017', '2018', '2019')
date_range = c("-03-01","-06-01 12:00")
date_range2 = c("-05-01","-06-01 12:00")

# %% [markdown]
# ### March - June

# %%
load(paste0('./share/data/', files[1]))
data
data_filter = filter_vpts(data,
                          min=paste0(years[1],date_range[1]),
                          max=paste0(years[1],date_range[2]))
plot(integrate_profile(data_filter))
# Out:
#                    Irregular time series of vertical profiles (class vpts)
#
#            radar:  KOKX
#       # profiles:  32311
# time range (UTC):  2016-01-01 00:01:23 - 2016-12-31 21:46:47
#    time step (s):  min: 12     max:  161997
# Plot with title “MTR”

# %%
load(paste0('./share/data/', files[2]))
data
data_filter = filter_vpts(data,
                          min=paste0(years[2],date_range[1]),
                          max=paste0(years[2],date_range[2]))
plot(integrate_profile(data_filter))
# Out:
#                    Irregular time series of vertical profiles (class vpts)
#
#            radar:  KOKX
#       # profiles:  31819
# time range (UTC):  2017-01-01 00:05:35 - 2017-12-31 21:42:17
#    time step (s):  min: 1     max:  227235
# Plot with title “MTR”

# %%
load(paste0('./share/data/', files[3]))
data
data_filter = filter_vpts(data,
                          min=paste0(years[3],date_range[1]),
                          max=paste0(years[3],date_range[2]))
plot(integrate_profile(data_filter))
# Out:
#                    Irregular time series of vertical profiles (class vpts)
#
#            radar:  KOKX
#       # profiles:  33848
# time range (UTC):  2018-01-01 00:09:12 - 2018-12-31 21:45:38
#    time step (s):  min: 152     max:  161938
# Plot with title “MTR”

# %%
load(paste0('./share/data/', files[4]))
data
data_filter = filter_vpts(data,
                          min=paste0(years[4],date_range[1]),
                          max=paste0(years[4],date_range[2]))
plot(integrate_profile(data_filter))
# Out:
#                    Irregular time series of vertical profiles (class vpts)
#
#            radar:  KOKX
#       # profiles:  21772
# time range (UTC):  2019-01-01 - 2019-09-01 10:14:31
#    time step (s):  min: 151     max:  57317
# Plot with title “MTR”

# %% [markdown]
# ### May - June

# %%
load(paste0('./share/data/', files[1]))
data
data_filter = filter_vpts(data,
                          min=paste0(years[1],date_range2[1]),
                          max=paste0(years[1],date_range2[2]))
plot(integrate_profile(data_filter))
# Out:
#                    Irregular time series of vertical profiles (class vpts)
#
#            radar:  KOKX
#       # profiles:  32311
# time range (UTC):  2016-01-01 00:01:23 - 2016-12-31 21:46:47
#    time step (s):  min: 12     max:  161997
# Plot with title “MTR”

# %%
load(paste0('./share/data/', files[2]))
data
data_filter = filter_vpts(data,
                          min=paste0(years[2],date_range2[1]),
                          max=paste0(years[2],date_range2[2]))
plot(integrate_profile(data_filter))
# Out:
#                    Irregular time series of vertical profiles (class vpts)
#
#            radar:  KOKX
#       # profiles:  31819
# time range (UTC):  2017-01-01 00:05:35 - 2017-12-31 21:42:17
#    time step (s):  min: 1     max:  227235
# Plot with title “MTR”

# %%
load(paste0('./share/data/', files[3]))
data
data_filter = filter_vpts(data,
                          min=paste0(years[3],date_range2[1]),
                          max=paste0(years[3],date_range2[2]))
plot(integrate_profile(data_filter))
# Out:
#                    Irregular time series of vertical profiles (class vpts)
#
#            radar:  KOKX
#       # profiles:  33848
# time range (UTC):  2018-01-01 00:09:12 - 2018-12-31 21:45:38
#    time step (s):  min: 152     max:  161938
# Plot with title “MTR”

# %%
load(paste0('./share/data/', files[4]))
data
data_filter = filter_vpts(data,
                          min=paste0(years[4],date_range2[1]),
                          max=paste0(years[4],date_range2[2]))
plot(integrate_profile(data_filter))
# Out:
#                    Irregular time series of vertical profiles (class vpts)
#
#            radar:  KOKX
#       # profiles:  21772
# time range (UTC):  2019-01-01 - 2019-09-01 10:14:31
#    time step (s):  min: 151     max:  57317
# Plot with title “MTR”
